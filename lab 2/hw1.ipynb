# %% [markdown]
# <img width=300 height=300 src="vacuum.webp">

# %% [markdown]
# ## CS 470 Artificial Intelligence hw1
#
# You are to edit the file hw1.py, as described in the instructions.
# We have provided a solution file, hw1a.pyc, which is compiled bytecode that you may run.
#
# Below we demonstrate the code, both with and without graphics.

# %%
from hw1 import *

# %%
gv = GraphicVacuumEnvironment(10,10,bias=0.5,color={'Agent': (200,0,0), 'Dirt': (230, 115, 40), 'Wall': (100,100,100)})

# %%
rv = TraceAgent(BetterReflexVacuumAgent())
gv.add_thing(rv)
gv.get_world()
# Out:
# Can't find a valid program for Agent, falling back to default.
# [[[<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>]],
#  [[<Wall>], [<Agent>], [<Dirt>], [<Dirt>], [], [], [], [], [], [<Wall>]],
#  [[<Wall>],
#   [],
#   [],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [<Wall>]],
#  [[<Wall>], [], [<Dirt>], [], [<Dirt>], [], [<Dirt>], [], [], [<Wall>]],
#  [[<Wall>], [], [], [<Dirt>], [], [<Dirt>], [<Dirt>], [], [<Dirt>], [<Wall>]],
#  [[<Wall>], [<Dirt>], [], [], [<Dirt>], [], [], [<Dirt>], [<Dirt>], [<Wall>]],
#  [[<Wall>], [], [], [], [], [], [<Dirt>], [], [], [<Wall>]],
#  [[<Wall>], [], [<Dirt>], [<Dirt>], [<Dirt>], [], [], [], [<Dirt>], [<Wall>]],
#  [[<Wall>], [], [], [], [], [<Dirt>], [], [], [<Dirt>], [<Wall>]],
#  [[<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>]]]

# %%
rv.performance
# Out:
# 0

# %%
rv.location
# Out:
# (1, 1)

# %%
gv.run(10)
# Out:
# Can't find a valid program for Agent, falling back to default.
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksdbe78b19-46aa-49ca-a895-59b56b6468ac td {border: 1px solid white;}</style><table id="blocksdbe78b19-46aa-49ca-a895-59b56b6468ac" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 5]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 7]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 8]&#10;Color: (200, 200, 200)" style="width: 20px; heigh ...
# Agent at (1, 1) takes action Right with performance 0
# Can't find a valid program for Agent, falling back to default.
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks9894e473-e8b5-49cc-a9a7-5199b37ac9a6 td {border: 1px solid white;}</style><table id="blocks9894e473-e8b5-49cc-a9a7-5199b37ac9a6" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 5]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 7]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 8]&#10;Color: (200, 200, 200)" style="width: 20px; heigh ...
# Agent at (2, 1) takes action Right with performance -1
# Can't find a valid program for Agent, falling back to default.
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks8872047c-3eb8-46b1-af97-b9a9a6769ada td {border: 1px solid white;}</style><table id="blocks8872047c-3eb8-46b1-af97-b9a9a6769ada" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 5]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 7]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 8]&#10;Color: (200, 200, 200)" style="width: 20px; heigh ...
# Agent at (3, 1) takes action Down with performance -2
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blockseca27bcf-fbf3-4f25-84d4-1ff0b14197fc td {border: 1px solid white;}</style><table id="blockseca27bcf-fbf3-4f25-84d4-1ff0b14197fc" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 5]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 7]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 8]&#10;Color: (200, 200, 200)" style="width: 20p ...
# Agent at (3, 2) takes action Suck with performance -3
# Can't find a valid program for Agent, falling back to default.
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blockse26da5cc-db4a-4c71-be5a-8bcc78d20180 td {border: 1px solid white;}</style><table id="blockse26da5cc-db4a-4c71-be5a-8bcc78d20180" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 5]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [2, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 7]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 8]&#10;Color: (200, 200, 200)" style="width: 20px; hei ...
# Agent at (3, 2) takes action Right with performance 7
# Can't find a valid program for Agent, falling back to default.
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks119cb7b0-37de-4cdb-898a-f6f15e9dfce0 td {border: 1px solid white;}</style><table id="blocks119cb7b0-37de-4cdb-898a-f6f15e9dfce0" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 5]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 4]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [2, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 7]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 8]&#10;Color: (200, 200, 200)" style="width: 20px; hei ...
# Agent at (4, 2) takes action Down with performance 6
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks86cbbe76-ff3a-43d6-b29e-9473bbd8cdfd td {border: 1px solid white;}</style><table id="blocks86cbbe76-ff3a-43d6-b29e-9473bbd8cdfd" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 5]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 7]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 8]&#10;Color: (200, 200, 200)" style="width: 2 ...
# Agent at (4, 3) takes action Suck with performance 5
# Can't find a valid program for Agent, falling back to default.
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks040ee554-318c-43c5-81b8-ad9acb00860b td {border: 1px solid white;}</style><table id="blocks040ee554-318c-43c5-81b8-ad9acb00860b" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 5]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 7]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 8]&#10;Color: (200, 200, 200)" style="width: 2 ...
# Agent at (4, 3) takes action Up with performance 15
# Can't find a valid program for Agent, falling back to default.
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks35c0ae00-ba42-4dad-9f9c-d7dee663307d td {border: 1px solid white;}</style><table id="blocks35c0ae00-ba42-4dad-9f9c-d7dee663307d" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 5]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 4]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [2, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 7]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 8]&#10;Color: (200, 200, 200)" style="width: 20px; hei ...
# Agent at (4, 2) takes action Up with performance 14
# Can't find a valid program for Agent, falling back to default.
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksc14766bb-7ec5-44a3-8d49-fc89e83b4b4b td {border: 1px solid white;}</style><table id="blocksc14766bb-7ec5-44a3-8d49-fc89e83b4b4b" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 5]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 7]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 8]&#10;Color: (200, 200, 200)" style="width: 20px; hei ...
# Agent at (4, 1) takes action Right with performance 13
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks469363a8-dd20-4cbd-87ab-7e8413448961 td {border: 1px solid white;}</style><table id="blocks469363a8-dd20-4cbd-87ab-7e8413448961" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 5]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 4]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 7]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 8]&#10;Color: (200, 200, 200)" style="width: 2 ...

# %%
rv.location
# Out:
# (5, 1)

# %%
rv.performance
# Out:
# 12

# %% [markdown]
# Now we create a vacuum world without graphics.

# %%
nve = NewVacuumEnvironment(10,10,bias=0.5)

# %%
nrv = TraceAgent(BetterReflexVacuumAgent())
nve.add_thing(nrv)
nve.get_world()
# Out:
# Can't find a valid program for Agent, falling back to default.
# [[[<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>]],
#  [[<Wall>], [<Agent>], [], [], [], [], [<Dirt>], [<Dirt>], [], [<Wall>]],
#  [[<Wall>],
#   [<Dirt>],
#   [],
#   [],
#   [<Dirt>],
#   [],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [<Wall>]],
#  [[<Wall>], [], [<Dirt>], [], [], [<Dirt>], [], [<Dirt>], [], [<Wall>]],
#  [[<Wall>], [], [], [<Dirt>], [<Dirt>], [], [], [], [], [<Wall>]],
#  [[<Wall>], [<Dirt>], [], [], [], [], [], [<Dirt>], [<Dirt>], [<Wall>]],
#  [[<Wall>],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [],
#   [<Wall>]],
#  [[<Wall>], [], [], [], [<Dirt>], [<Dirt>], [], [], [], [<Wall>]],
#  [[<Wall>], [], [<Dirt>], [], [], [<Dirt>], [<Dirt>], [], [<Dirt>], [<Wall>]],
#  [[<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>]]]

# %%
nve.run(10)
# Out:
# Agent at (1, 1) takes action Left with performance 0
# Agent at (1, 1) takes action Left with performance -1
# Agent at (1, 1) takes action Down with performance -2
# Agent at (1, 2) takes action Left with performance -3
# Agent at (1, 2) takes action Right with performance -4
# Agent at (2, 2) takes action Up with performance -5
# Agent at (2, 1) takes action Suck with performance -6
# Agent at (2, 1) takes action Left with performance 4
# Agent at (1, 1) takes action Up with performance 3
# Agent at (1, 1) takes action Right with performance 2

# %%
nrv.location
# Out:
# (2, 1)

# %%
nrv.performance
# Out:
# 1

# %%
main()
# Out:
# hours
# # is it greater than 0?
#  OK  got: 25 expected: <function main.<locals>.<lambda> at 0x000002B7E34A7600>
# NewVacuumEnvironment - Walls
#  OK  got: '[[[<Wall>], [<Wall>], [<Wall>], [<Wall>], [<Wall>]], [[<Wall>], [], [], [], [<Wall>]], [[<Wall>], [], [], [], [<Wall>]], [[<Wall>], [], [], [], [<Wall>]], [[<Wall>], [<Wall>], [<Wall>], [<Wall>], [<Wall>]]]' expected: '[[[<Wall>], [<Wall>], [<Wall>], [<Wall>], [<Wall>]], [[<Wall>], [], [], [], [<Wall>]], [[<Wall>], [], [], [], [<Wall>]], [[<Wall>], [], [], [], [<Wall>]], [[<Wall>], [<Wall>], [<Wall>], [<Wall>], [<Wall>]]]'
# NewVacuumEnvironment - Dirt
#  OK  got: 145 expected: <function main.<locals>.<lambda> at 0x000002B7DCF01580>
# NewVacuumEnvironment - Very Clean
#  OK  got: 0 expected: 0
# NewVacuumEnvironment - Very Dirty
#  OK  got: 324 expected: 324
# TraceAgent and BetterReflexVacuumAgent
# Agent at (1, 1) takes action Suck with performance 0
#  OK  got: (1, 1) expected: (1, 1)
#  OK  got: 10 expected: 10
# Agent at (1, 1) takes action Right with performance 10
# Agent at (2, 1) takes action Suck with performance 9
# Agent at (2, 1) takes action Down with performance 19
# Agent at (2, 2) takes action Suck with performance 18
# Agent at (2, 2) takes action Up with performance 28
# Agent at (2, 1) takes action Up with performance 27
# Agent at (2, 1) takes action Up with performance 26
# Agent at (2, 1) takes action Left with performance 25
# Agent at (1, 1) takes action Down with performance 24
# Agent at (1, 2) takes action Suck with performance 23
# Agent at (1, 2) takes action Left with performance 33
# Agent at (1, 2) takes action Right with performance 32
# Agent at (2, 2) takes action Left with performance 31
# Agent at (1, 2) takes action Right with performance 30
# Agent at (2, 2) takes action Right with performance 29
# Agent at (3, 2) takes action Suck with performance 28
# Agent at (3, 2) takes action Left with performance 38
# Agent at (2, 2) takes action Up with performance 37
# Agent at (2, 1) takes action Down with performance 36
# Agent at (2, 2) takes action Left with performance 35
#  OK  got: 34 expected: <function main.<locals>.<lambda> at 0x000002B7E34A7060>

# %% [markdown]
# Below we demonstrate the testing code from the end of agents.py

# %%
environment = TrivialVacuumEnvironment

# %%
agents = [ModelBasedVacuumAgent, ReflexVacuumAgent]

# %%
result = compare_agents(environment, agents)

# %%
result
# Out:
# [(<function agents.ModelBasedVacuumAgent()>, 12),
#  (<function agents.ReflexVacuumAgent()>, -985.7)]
